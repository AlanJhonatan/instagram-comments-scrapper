# %%
import time                                     #to use time.sleep()
from seleniumwire import webdriver              # using seleniumwire to allow inspect network requests/responses 
from seleniumwire.webdriver import ActionChains # using ActionChains to trigger .click() event on any kind of element

# %%
import json
from requests import Request, Session

# %%
import pandas as pd

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import matplotlib.pyplot as plt

# %%
#Post search variables

#'https://www.instagram.com/p/B-pln9YJ_6z/'
#'https://www.instagram.com/p/CIc3JKOBVRZ/'

postUrl = 'https://www.instagram.com/p/CGYbktFBr1S/'

postUrl
# Out:
# 'https://www.instagram.com/p/CGYbktFBr1S/'

# %%
def urlfier (arr):
    return str(''.join(arr))

urlfier(['Its ', 'working ', 'perfectly ', '!'])
# Out:
# 'Its working perfectly !'

# %%
def queryExtractor(url):
    return url[url.find('after%22%3A%22') + len('after%22%3A%22') : url.find('%3D%3D%22%7D')]

#queryExtractor(requestUrl)

# %%
#get the post hash
postHash = postUrl[28:len(postUrl) - 1]
postHash
# Out:
# 'CGYbktFBr1S'

# %%
#static variables
queryHash = 'https://www.instagram.com/graphql/query/?query_hash='
matches = [postHash, queryHash, 'shortcode', 'first', 'after']
total_comments = 0

# %%
#using ChromeDriver
print('Wait browser open in post page !')
driver = webdriver.Chrome('./chromedriver.exe')
driver.get(postUrl)
print('Ready to go !')
# Out:
# Wait browser open in post page !
# Ready to go !

# %%
#class of 'load more' button -> glyphsSpriteCircle_add__outline__24__grey_9 u-__7 (detected manually)
#handling the element based on his class
element = driver.find_element_by_class_name('glyphsSpriteCircle_add__outline__24__grey_9.u-__7')
element
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="30a0d5f9acd55d0e5b13af1d91ce6bab", element="199dfc0b-dffa-48e3-b1f7-d60e5d202619")>

# %%
# trigger the button to make next page request
element.click()

# %%
#handle the url of Instagram GraphQL comments endpoint 
requestUrl = ''

#search the endpoint url
for request in driver.requests:
    if all(x in request.url for x in matches):
        requestUrl = request.url

requestUrl
# Out:
# 'https://www.instagram.com/graphql/query/?query_hash=bc3296d1ce80a24b1b6e40b1e72903f5&variables=%7B%22shortcode%22%3A%22CGYbktFBr1S%22%2C%22first%22%3A18%2C%22after%22%3A%22QVFCYTNVek45eVBPNF9ZRnJMa2lCOXNOR1kzOWdJX1NLZlVyZy1HTlNqcU5fUWh5cVpWMXR3N1BSc1BKUDNBQnJGZlZWSS1oc3Y1NEZiWFM1T0lHLXowaw%3D%3D%22%7D'

# %%
#handle all hash of all pages
pagesHash = []
pagesHash.append(queryExtractor(requestUrl))

pagesHash
# Out:
# ['QVFCYTNVek45eVBPNF9ZRnJMa2lCOXNOR1kzOWdJX1NLZlVyZy1HTlNqcU5fUWh5cVpWMXR3N1BSc1BKUDNBQnJGZlZWSS1oc3Y1NEZiWFM1T0lHLXowaw']

# %%
#Settin Up the custom request infos

headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36",
    "Host": "www.instagram.com",
    "Sec-Fetch-Dest": "document",
    "Sec-Fetch-Mode": "navigate",
}

headers
# Out:
# {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
#  'Host': 'www.instagram.com',
#  'Sec-Fetch-Dest': 'document',
#  'Sec-Fetch-Mode': 'navigate'}

# %%
URL = [
        queryHash,
        requestUrl[requestUrl.find('?query_hash=') + len('?query_hash=') : 158 + len('after%22%3A%22')], # variables
        pagesHash[-1], # pagination hash idx 2
        '%3D%3D%22%7D',
      ]

urlfier(URL)
# Out:
# 'https://www.instagram.com/graphql/query/?query_hash=bc3296d1ce80a24b1b6e40b1e72903f5&variables=%7B%22shortcode%22%3A%22CGYbktFBr1S%22%2C%22first%22%3A18%2C%22after%22%3A%22QVFCYTNVek45eVBPNF9ZRnJMa2lCOXNOR1kzOWdJX1NLZlVyZy1HTlNqcU5fUWh5cVpWMXR3N1BSc1BKUDNBQnJGZlZWSS1oc3Y1NEZiWFM1T0lHLXowaw%3D%3D%22%7D'

# %%
# Prepare the first request

prepped = Request('GET',
                  urlfier(URL),
                  headers=headers,
                 ).prepare()

prepped
# Out:
# <PreparedRequest [GET]>

# %%
# Request Handler
reqHandler = []

# Edges Handler
#edgesHandler = []

reqHandler#, edgesHandler
# Out:
# []

# %%
# Session Setup
s = Session() 

# Making the request
resp = s.send(prepped) 

reqHandler.append(resp.json())

resp, len(reqHandler)
# Out:
# (<Response [200]>, 1)

# %%
total_comments = reqHandler[0]['data']['shortcode_media']['edge_media_to_parent_comment']['count']
total_comments
# Out:
# 4464

# %%
# Setup some variables

# Get if Has Next Page 
has_next = reqHandler[-1]['data']['shortcode_media']['edge_media_to_parent_comment']['page_info']['has_next_page']

# Get the Next Page Hash
next_hash = reqHandler[-1]['data']['shortcode_media']['edge_media_to_parent_comment']['page_info']['end_cursor'][:(-2)]

# Append second hash in list
pagesHash.append(next_hash)

has_next, next_hash, pagesHash
# Out:
# (True,
#  'QVFCZ29aYnZtX3c5aHZUUWhpNjFhM3FNNld0ejFuaFdRT21udWtmYlRFRmo5SGVPSTBqbHJOTHZTNThvNkNkWnRjZk5RbnhuYWdCYVdFQl8xbFprZ3hDVg',
#  ['QVFCYTNVek45eVBPNF9ZRnJMa2lCOXNOR1kzOWdJX1NLZlVyZy1HTlNqcU5fUWh5cVpWMXR3N1BSc1BKUDNBQnJGZlZWSS1oc3Y1NEZiWFM1T0lHLXowaw',
#   'QVFCZ29aYnZtX3c5aHZUUWhpNjFhM3FNNld0ejFuaFdRT21udWtmYlRFRmo5SGVPSTBqbHJOTHZTNThvNkNkWnRjZk5RbnhuYWdCYVdFQl8xbFprZ3hDVg'])

# %%
req_count = 1
while has_next:
    
    URL[2] = next_hash
    prepped.url = urlfier(URL)
    
    resp = s.send(prepped)
    print(f'{req_count} requests made.')
    req_count += 1
    
    reqHandler.append(resp.json())
    
    has_next = reqHandler[-1]['data']['shortcode_media']['edge_media_to_parent_comment']['page_info']['has_next_page']
    next_hash = reqHandler[-1]['data']['shortcode_media']['edge_media_to_parent_comment']['page_info']['end_cursor'][:(-2)]
    time.sleep(1)

len(reqHandler)
# Out:
# 1 requests made.
# 2 requests made.
# 3 requests made.
# 4 requests made.
# 5 requests made.
# 6 requests made.
# 7 requests made.
# 8 requests made.
# 9 requests made.
# 10 requests made.
# 11 requests made.
# 12 requests made.
# 13 requests made.
# 14 requests made.
# 15 requests made.
# 16 requests made.
# 17 requests made.
# 18 requests made.
# 19 requests made.
# 20 requests made.
# 21 requests made.
# 22 requests made.
# 23 requests made.
# 24 requests made.
# 25 requests made.
# 26 requests made.
# 27 requests made.
# 28 requests made.
# 29 requests made.
# 30 requests made.
# 31 requests made.
# 32 requests made.
# 33 requests made.
# 34 requests made.
# 35 requests made.
# 36 requests made.
# 37 requests made.
# 38 requests made.
# 39 requests made.
# 40 requests made.
# 41 requests made.
# 42 requests made.
# 43 requests made.
# 44 requests made.
# 45 requests made.
# 46 requests made.
# 47 requests made.
# 48 requests made.
# 49 requests made.
# 50 requests made.
# 51 requests made.
# 52 requests made.
# 53 requests made.
# 54 requests made.
# 55 requests made.
# 56 requests made.
# 57 requests made.
# 58 requests made.
# 59 requests made.
# 60 requests made.
# 61 requests made.
# 62 requests made.
# 63 requests made.
# 64 requests made.
# 65 requests made.
# 66 requests made.
# 67 requests made.
# 68 requests made.
# 69 requests made.
# 70 requests made.
# 71 requests made.
# 72 requests made.
# 73 requests made.
# 74 requests made.
# 75 requests made.
# 76 requests made.
# 77 requests made.
# 78 requests made.
# 79 requests made.
# 80 requests made.
# 81 requests made.
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-23-15d77d7cd2bd> in <module>
#       9     req_count += 1
#      10
# ---> 11     reqHandler.append(resp.json())
#      12
#      13     has_next = reqHandler[-1]['data']['shortcode_media']['edge_media_to_parent_comment']['page_info']['has_next_page']
#
# c:\python38\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# c:\python38\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# c:\python38\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\python38\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
has_next

# %%
res_handler = reqHandler

len(res_handler) == len(reqHandler)
# Out:
# True

# %%
edges_handler = []

# %%
 res_handler[0]['data']['shortcode_media']['edge_media_to_parent_comment']['edges']
# Out:
# [{'node': {'id': '17866564949099783',
#    'text': 'A prestação do apartamento é debitada dia 18 todo mês. Esse mes 18 é domingo. A CEF debita na sexta dia 16. Sacanagem demais. 😠😡🤬',
#    'created_at': 1603032616,
#    'did_report_as_spam': False,
#    'owner': {'id': '9907778000',
#     'is_verified': False,
#     'profile_pic_url': 'https://scontent-gru2-2.cdninstagram.com/v/t51.2885-19/s150x150/128660703_917382495735914_8925898627896099989_n.jpg?_nc_ht=scontent-gru2-2.cdninstagram.com&_nc_ohc=-j7bPCrbI7cAX_8Mxdx&tp=1&oh=b576c0e04284fa95799cbe85b51ff199&oe=60096E60',
#     'username': 'gildoferrazoficial'},
#    'viewer_has_liked': False,
#    'edge_liked_by': {'count': 0},
#    'is_restricted_pending': False,
#    'edge_threaded_comments': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []}}},
#  {'node': {'id': '17864095427132907',
#    'text': '👏👏👏👏👏👏🙏🏻',
#    'created_at': 1603033358,
#    'did_report_as_spam': False,
#    'owner': {'id': '9466729408',
#     'is_verified': False,
#     'profile_pic_url': 'https://scontent-gru2-2.cdninstagram.com/v/t51.2885-19/s150x150/104074449_595662594420537_9127209022466420207_n.jpg?_nc_ht=scontent-gru2-2.cdninstagram.com&_nc_ohc=Nn4xmSj1NZAAX-t7u9Z&tp=1&oh=9f7ed79a4bd9eaf5d928183229b3ee2d&oe=60080929',
#     'username': 'selma_francisquetto'},
#    'viewer_has_liked': False,
#    'edge_liked_by': {'count': 0},
#    'is_restricted_pending': False,
#    'edge_threaded_comments': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []}}},
#  {'node': {'id': '17869928084043585',
#    'text': '👍👍👍\n #bolsonarotemrazão \n  SEMPRE TEVE \n 😎👊👊',
#    'created_at': 1603034594,
#    'did_report_as_spam': False,
#    'owner': {'id': '6263041196',
#     'is_verified': False,
#     'profile_pic_url': 'https://instagram.fzrh1-1.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fzrh1-1.fna.fbcdn.net&_nc_ohc=L111VlxDSxEAX-N85KI&oh=7cafea7742216d300ef7d4bf0c059a8b&oe=6008E38F&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2',
#     'username': 'denise.belmont'},
#    'viewer_has_liked': False,
#    'edge_liked_by': {'count': 1},
#    'is_restricted_pending': False,
#    'edge_threaded_comments': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []}}},
#  {'node': {'id': '17870454911026328',
#    'text': '👏',
#    'created_at': 1603037995,
#    'did_report_as_spam': False,
#    'owner': {'id': '7400197730',
#     'is_verified': False,
#     'profile_pic_url': 'https://scontent-gru2-2.cdninstagram.com/v/t51.2885-19/s150x150/100940634_693865718044387_5678412283932311552_n.jpg?_nc_ht=scontent-gru2-2.cdninstagram.com&_nc_ohc=dMT3jz1DxjQAX-j2HRj&tp=1&oh=683649c306a8afed11ba1fe3e5c15f6f&oe=6008DF80',
#     'username': 'carlosferreira4777'},
#    'viewer_has_liked': False,
#    'edge_liked_by': {'count': 0},
#    'is_restricted_pending': False,
#    'edge_threaded_comments': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []}}},
#  {'node': {'id': '17844017939429968',
#    'text': '🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧�
�🏼👏🏼👏🏼👏🏼👏🏼👏🏼',
#    'created_at': 1603055735,
#    'did_report_as_spam': False,
#    'owner': {'id': '5484527491',
#     'is_verified': False,
#     'profile_pic_url': 'https://scontent-gru2-2.cdninstagram.com/v/t51.2885-19/s150x150/88921874_507292483515702_6150920439532093440_n.jpg?_nc_ht=scontent-gru2-2.cdninstagram.com&_nc_ohc=6nW56dSEMacAX-idbGd&tp=1&oh=cc493f61e497077e0e5100a055f56f52&oe=60096FF6',
#     'username': 'elisamoraesadv'},
#    'viewer_has_liked': False,
#    'edge_liked_by': {'count': 0},
#    'is_restricted_pending': False,
#    'edge_threaded_comments': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []}}},
#  {'node': {'id': '17897115022628279',
#    'text': 'Leite mais de $4, gasolina tbm, arroz virou caviar...carne artigo de luxo...esse povo que apoia Bolsonaro deve ganhar em dólar não é possível!!!!',
#    'created_at': 1603056167,
#    'did_report_as_spam': False,
#    'owner': {'id': '7481697890',
#     'is_verified': False,
#     'profile_pic_url': 'https://scontent-gru2-2.cdninstagram.com/v/t51.2885-19/s150x150/106280812_677320506334049_6447008867078008288_n.jpg?_nc_ht=scontent-gru2-2.cdninstagram.com&_nc_ohc=M2LyVwxwFDgAX_uK72j&tp=1&oh=85743a8e42a98834053eb96a76372e57&oe=60073711',
#     'username': 'anabrandolise'},
#    'viewer_has_liked': False,
#    'edge_liked_by': {'count': 0},
#    'is_restricted_pending': False,
#    'edge_threaded_comments': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []}}},
#  {'node': {'id': '17891109967713739',
#    'text': 'meu namorado👩\u200d❤️\u200d💋\u200d👨👩\u200d❤️\u200d💋\u200d👨é mó otario🖕🏽🖕🏽🤬🤬ele👨🏼👨🏼lava💦💦💦minhas👩🏻👩🏻calcinha🩲🩲🩲\nSe ele👨🏼👨🏼fica cheio de marra💪🏻💪🏻💪🏻mando ele pra cozinha👨🏼\u200d🍳👨🏼\u200d🍳\nSe tu não tá gostando🤬🖕🏽🤬🖕🏽então dorme💤💤no portão🚪🚪\nPor que eu 👩🏻👩🏻 vou pro baile🥳🥳🎉🎊🎉vou pra minha curtição 😎😜😎😜😎',
#    'created_at': 1603060996,
#    'did_report_as_spam': False,
#    'owner': {'id': '9382370995',
#     'is_verified': False,
#     'profile_pic_url': 'https://scontent-gru2-2.cdninstagram.com/v/t51.2885-19/s150x150/128242178_2771342699786565_6853184551139742350_n.jpg?_nc_ht=scontent-gru2-2.cdninstagram.com&_nc_ohc=iVDRr1lOR6EAX-RcV9Z&tp=1&oh=58dd5e6f6cbbb689d3f62d8710166943&oe=6009BEB8',
#     'username': 'rosieparkkkk'},
#    'viewer_has_liked': False,
#    'edge_liked_by': {'count': 0},
#    'is_restricted_pending': False,
#    'edge_threaded_comments': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []}}},
#  {'node': {'id': '17860672070157565',
#    'text': 'Meu pai, e eu votei nesse troço',
#    'created_at': 1603063566,
#    'did_report_as_spam': False,
#    'owner': {'id': '1954445130',
#     'is_verified': False,
#     'profile_pic_url': 'https://scontent-gru2-2.cdninstagram.com/v/t51.2885-19/s150x150/125351855_380633860038084_3845379539378928554_n.jpg?_nc_ht=scontent-gru2-2.cdninstagram.com&_nc_ohc=h2NHLS-O-XcAX94hN28&tp=1&oh=451261404bad1f3e8b280575bcca7b9c&oe=600819AC',
#     'username': 'la_na_andromeda'},
#    'viewer_has_liked': False,
#    'edge_liked_by': {'count': 0},
#    'is_restricted_pending': False,
#    'edge_threaded_comments': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []}}},
#  {'node': {'id': '17884375687748894',
#    'text': 'Olha o linguajar distante desse cidadão "essas crianças" porque não dizer, nossas crianças brasileiras, e porque não apresenta um material de qualidade pra nossas crianças, material construído pelas mãos dos nossos professores, eles que  estão mais próximo da realidade da nossa educação',
#    'created_at': 1603064777,
#    'did_report_as_spam': False,
#    'owner': {'id': '1954445130',
#     'is_verified': False,
#     'profile_pic_url': 'https://scontent-gru2-2.cdninstagram.com/v/t51.2885-19/s150x150/125351855_380633860038084_3845379539378928554_n.jpg?_nc_ht=scontent-gru2-2.cdninstagram.com&_nc_ohc=h2NHLS-O-XcAX94hN28&tp=1&oh=451261404bad1f3e8b280575bcca7b9c&oe=600819AC',
#     'username': 'la_na_andromeda'},
#    'viewer_has_liked': False,
#    'edge_liked_by': {'count': 0},
#    'is_restricted_pending': False,
#    'edge_threaded_comments': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []}}}]

# %%
# reset de edges handler just in case
edges_handler = []

# %%
#extract all comments to an serialized array of comments. 
for req in res_handler:
    for node in req['data']['shortcode_media']['edge_media_to_parent_comment']['edges']:
        edges_handler.append(node['node'])
        
print(f'"edges_handler" has {len(edges_handler)} comments in total.')
# Out:
# "edges_handler" has 1339 comments in total.

# %%
# Sample of content
edges_handler[100]
# Out:
# {'id': '17882355754834391',
#  'text': "Sr pres bolsonaro votei com orgulho em Vsa não me faça arrepender,  o senhor tá cercado de militares e divr's doutores mas não vi ngm dizer oque deveria ser dito ! E claro por falta de uma outra visão de td's q o cercam o sr falou oque achou certo ,mas o certo seria Vsa dizer : o traficante foi solto isso foi um erro e se eu errei como a mídia diz porq não vetei o art.316 nada justifica o supremo errar também, pois dois errados não faz um certo! Se agarrar em erros de outros ou na letra fria da lei pra soltar bandido explica mas não justifica,  a lei foi criada para proteger a sociedade e o cidadão de bem e não proteger bandido !!! Sei que essa minha manifestação ñ vai dar em nada tenho + de 650 manifestações sobre divr's assuntos e sugestões e denúncias  encaminhada ao senhor ngm responde já perdi tempo qndo fui até gabinete do flavio bolsonaro e lá fui recebido por um baixinho careca (coronel braga)metido a brabo q grita com os colegas no gabinete grita  no telefone em fim poço de ignorância e claro ñ entendeu nada sobre oque conversamos e como fiquei lá aproximadamente 3hs aguardando ser atendido fiz amizade com membro do gabinete e soube q depois q eu sai do gabinete o mesmo rasgou dossiê endereçado ao pres.bolsonsro e jogou no lixo ah esperei 3hs embora tivesse hora marcada e fui dispensado em 5 minutos tá,  aí me pergunto porque um tralha desse é chefe gabinete hein? E será q ele é brabo mesmo serviu na aeronáutica e eu na infantaria sou infante fuzileiro logo não dá pra comparar com essa água com açúcar da aeronáutica né. Boa sorte bolsonaro com essas tralhas tipo hélio Lopes se te contar oque ele e seu chefe gabinete sr Jackson me disse Vsa vai cair duro pra trás mas não Lima só esses não tem também Cinara lima, denise verberling, pastor Marco Feliciano e sua chefe gabinete mara, Marco rassier, são mt's inaptos ao seu redor posso afirmar pois tenho 650 contatos e dessas 650 demandas endereçadas a Vsa qntas chegou até suas mãos bolsonsro ?",
#  'created_at': 1602941693,
#  'did_report_as_spam': False,
#  'owner': {'id': '499144882',
#   'is_verified': False,
#   'profile_pic_url': 'https://scontent-gru2-2.cdninstagram.com/v/t51.2885-19/11348243_927636300634371_1405982383_a.jpg?_nc_ht=scontent-gru2-2.cdninstagram.com&_nc_ohc=PtwYU6VKGPQAX835c3L&oh=d33a6f191ce85c17a9ca7968d1a09b55&oe=60088D4E',
#   'username': 'betto_eu'},
#  'viewer_has_liked': False,
#  'edge_liked_by': {'count': 0},
#  'is_restricted_pending': False,
#  'edge_threaded_comments': {'count': 0,
#   'page_info': {'has_next_page': False, 'end_cursor': None},
#   'edges': []}}

# %%
result = []
replies = 0

result, replies
# Out:
# ([], 0)

# %%
# Starting DFS
for comment in edges_handler:
    result.append({
        "owner_id": comment['owner']['id'], # id owner
        "owner_username": comment['owner']['username'], # username
        "owner_verified": comment['owner']['is_verified'], # verified
        "owner_picture": comment['owner']['profile_pic_url'], # picture
        "comment": comment['text'], # comment
        "replies": comment['edge_threaded_comments']['count'], #replies
    })
    replies += int(comment['edge_threaded_comments']['count'])
    
len(result), replies
# Out:
# (1339, 41)

# %%
df = pd.DataFrame.from_dict(result)

df.head()
# Out:
#       owner_id       owner_username  owner_verified  \
# 0   9907778000   gildoferrazoficial           False
# 1   9466729408  selma_francisquetto           False
# 2   6263041196       denise.belmont           False
# 3   7400197730   carlosferreira4777           False
# 4  32109604280         lucianoflu99           False
#
#                                        owner_picture  \
